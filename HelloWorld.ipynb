# %% [markdown]
# <a href="https://colab.research.google.com/github/aramisgibson/MIS2800/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print ("mis is best!")

# %% [markdown]
# <a href="https://colab.research.google.com/github/aramisgibson/MIS2800/blob/main/Gibson_HW3_Wk4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Type this code exactly as shown to intall the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 53.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: prettytable
#     Found existing installation: prettytable 3.17.0
#     Uninstalling prettytable-3.17.0:
#       Successfully uninstalled prettytable-3.17.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.0 which is incompatible.
# ...

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been im
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.d
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
# Bug fixes

# %%
#Block 1
# Instructions: There is a typo in the table. Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
brand_id INTEGER PRIMARY KEY,
brand_name TEXT,
brand_type TEXT,
brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) table Marketing_Brands already exists
# [SQL: CREATE TABLE Marketing_Brands (
# brand_id INTEGER PRIMARY KEY,
# brand_name TEXT,
# brand_type TEXT,
# brand_budget INTEGER
# ) STRICT;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 2
# Instructions: Find and fix the error.
# %%sql
INSERT INTO Marketing_Brands(brand_id, brand_name, brand_type, brand_budget)
VALUES
(1, 'Doritos', 'Snacks', 7000000),
(2, 'AWS', 'Technology', 15000000),
(3, 'Pepsi', 'Beverages', 2000000),
(4, 'He_Gets_Us', 'Religious', 1000000),
(5, 'Dr_Pepper', 'Beverages', 5000000),
(6, 'IBM', 'Technology', 100000),
(7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.IntegrityError) UNIQUE constraint failed: Marketing_Brands.brand_id
# [SQL: INSERT INTO Marketing_Brands(brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Us', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
#Block 3
# %%sql
-- Instructions: Fix the code to select all the columns from the Marketing
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4
# %%sql
-- Instructions: Fix the code to display only the brand names and
--brand types that had budget over 700000
SELECT * FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# %%sql
-- Instructions: Fix the code to display
--the brand names that have a budget under 1000000
SELECT * FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000)]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in Colab without
#having to wrap in Python. Hint: Its Magic!
# %%sql sqlite:///Adcampaigns2026.db
SELECT * FROM Marketing_Brands WHERE brand_budget > 700000;
# Out:
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8
# %%sql
--Instructions: Find the brands where the brand type is
--Snacks or Beverages. Display only the brand names.
SELECT  brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
#Block 9
# %%sql
-- Instructions: Sort the table by brand budget in
--DESC order. Display only the brand_name and brand_budget.
SELECT * FROM Marketing_Brands ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000),
#  (7, 'Google', 'Technology', 8000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql sqlite:///Adcampaigns2026.db
SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
# Out:
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# 1. was missing TABLE
# 2. was missing Marketing_Brands
# 3. added a *
# 4. SELECT * FROM Marketing_Brands WHERE brand_budget > 700000;
# 5. SELECT * FROM Marketing_Brands WHERE brand_type = 'Religous';
# 6. SELECT * FROM Marketing_Brands WHERE brand_budget < 1000000;
# 7. SELECT * FROM Marketing_Brands WHERE brand_budget > 700000;

# %% [markdown]
# 8.SELECT  brand_name FROM Marketing_Brands WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
#
# 9.SELECT * FROM Marketing_Brands ORDER BY brand_budget DESC;
#
# 10.SELECT * FROM Marketing_Brands ORDER BY brand_budget ASC;
